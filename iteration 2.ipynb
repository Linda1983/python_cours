# %%
import pandas as pd

# %%
data = pd.read_csv("trees.csv", sep =  ';')
# Out:
# /tmp/ipykernel_38336/3047102037.py:1: DtypeWarning: Columns (22,23,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("trees.csv", sep =  ';')

# %% [markdown]
# # Pour commencer, identifiez tous les genres botaniques représentés à Grenoble.Combien y en a-t-il ? Essayez plusieurs manières de résoudre ce problème.

# %%
genre_botanique = data.groupby('genre_bota')['elem_point_id'].count()
genre_botanique
# Out:
# genre_bota
# Abies             27
# Acacia             1
# Acer            5047
# Aesculus         447
# Ailanthus         75
#                 ...
# Tilia           1741
# Trachycarpus      22
# Ulmus            241
# Zelkova          306
# inconnu          122
# Name: elem_point_id, Length: 116, dtype: int64

# %% [markdown]
# # Identifiez maintenant toutes les espèces différentes présentes à Grenoble.N’oubliez pas que les espèces sont une sous catégorie de genre botanique !(l’espèce est ‘Platanus Acerifolia’ et pas uniquement ‘Acerifolia’)

# %%
distinct_espece = data['genre_bota'].value_counts()
distinct_espece
# Out:
# genre_bota
# Acer          5047
# Platanus      4453
# Pinus         1923
# Tilia         1741
# Fraxinus      1528
#               ...
# Poncinos         1
# Eucalyptus       1
# Castanea         1
# Sorbopyrus       1
# Sterculia        1
# Name: count, Length: 116, dtype: int64

# %% [markdown]
# # En utilisant la structure de données Dict compter le nombre de représentants de chaque genre botanique : Quel est le genre botanique le plus représenté ?

# %% [markdown]
# # Listez tous les représentants uniques de leurs genre botanique

# %%
unique_genre_botanique = data['genre_bota'].unique()
unique_genre_botanique
# Out:
# array(['Ginkgo', 'Platanus', 'Morus', 'Taxus', 'Acer', 'Prunus', 'Cercis',
#        'Pinus', 'Tilia', 'Gleditsia', 'Celtis', 'Cedrus', 'Carpinus',
#        'Juglans', 'Fraxinus', 'Chamaecyparis', 'Quercus', 'Salix',
#        'Betula', 'Sophora', 'Populus', 'Cupressus', 'Pyrus', 'Alnus',
#        'Fagus', 'Malus', 'Liquidambar', 'Ulmus', 'Liriodendron',
#        'Crataegus', 'Robinia', 'Catalpa', 'Magnolia', 'Paulownia',
#        'Aesculus', 'Koelreuteria', 'Picea', 'Cedrela', 'Broussonetia',
#        'Punica', 'Mespilus', 'Amélanchier', 'Parrotia', 'Sorbus',
#        'Metasequoia', nan, 'Gymnocladus', 'Taxodium', 'Zelkova',
#        'Lagerstroemia', 'inconnu', 'Ostrya', 'Corylus', 'Tetradium',
#        'Juniperus', 'Pistacia', 'Chionanthus', 'Phellodendron', 'Davidia',
#        'Halesia', 'Maclura', 'Ficus', 'Cercidiphyllum', 'Albizia',
#        'Pterocarya', 'Eleagnus', 'Thuja', 'Ilex', 'Carya', 'Castanea',
#        'Cornus', 'Sequoiadendron', 'Cupressocyparis', 'Calocedrus',
#        'Ailanthus', 'Clerodendron', 'Larix', 'Pteroceltis',
#        'Trachycarpus', 'Abies', 'Olea', 'Sambucus', 'Cotinus', 'Photinia',
#        'Buxus', 'Cydonia', 'Cephalotaxus', 'Ptelea', 'Sequoia',
#        'Diospyros', 'Poncinos', 'Chimonanthus', 'Phillyrea', 'Sorbopyrus',
#        'Hovenia', 'Lonicera', 'Eriobotrya ', 'Laburnum', 'Eucalyptus',
#        'Rhus', 'Ligustrum', 'Syringa', 'Chitalpa', 'Rhamnus',
#        'Cladastris', 'Styrax', 'Fontanesia', 'Pterostyrax', 'Nyssa',
#        'Staphylea', 'Acacia', 'Pseudotsuga', 'Araucaria', 'Cryptomeria',
#        'Idesia', 'Hibiscus', 'Sterculia'], dtype=object)

# %% [markdown]
# # Classer tous les genres botaniques en fonction de leur nombre (ordredécroissant)

# %%
sort_botanique_desc = data.sort_values(['genre_bota'], ascending = [False])
sort_botanique_desc
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 29735        45261.0  ESP41054  AR41054   VEG  VEGETATION     ESP01
# 470          47465.0  ESP42968  AR42968   VEG  VEGETATION     ESP01
# 466          47461.0  ESP42964  AR42964   VEG  VEGETATION     ESP01
# 467          47462.0  ESP42965  AR42965   VEG  VEGETATION     ESP01
# 468          47463.0  ESP42966  AR42966   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 30181        45858.0  ESP41429  AR41429   VEG  VEGETATION     ESP01
# 30182        45859.0  ESP41430  AR41430   VEG  VEGETATION     ESP01
# 30183        45860.0  ESP41431  AR41431   VEG  VEGETATION     ESP01
# 30253        45874.0  ESP41445  AR41445   VEG  VEGETATION     ESP01
# 30254        45875.0  ESP41446  AR41446   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 29735          Arbre         ESP151          Arbre de voirie    ESP41038  ...
# 470            Arbre         ESP174  Arbre d'espaces ouverts     ESP1102  ...
# 466            Arbre         ESP174  Arbre d'espaces ouverts     ESP1102  ...
# 467            Arbre         ESP174  Arbre d'espaces ouverts     ESP1102  ...
# 468            Arbre         ESP174  Arbre d'espaces ouverts     ESP1102  ...
# ...              ...            ...                      ...         ...  ...
# 30181          Arbre         ESP174  Arbre d'espaces ouverts     ESP1166  ...
# 30182          Arbre         ESP174  Arbre d'espaces ouverts     ESP1166  ...
# 30183          Arbre         ESP174  Arbre d'espaces ouverts      ESP753  ...
# 30253          Arbre         ESP174  Arbre d'espaces ouverts      ESP439  ...
# 30254          Arbre         ESP174  Arbre d'espaces ouverts      ESP439  ...
#
#       diametrearbre  causeabattage              collectivite stationmetro  \
# 29735           NaN            NaN  Grenoble Alpes Métropole          NaN
# 470             NaN            NaN  Grenoble Alpes Métropole          NaN
# 466             NaN            NaN  Grenoble Alpes Métropole          NaN
# 467             NaN            NaN  Grenoble Alpes Métropole          NaN
# 468             NaN            NaN  Grenoble Alpes Métropole          NaN
# ...             ...            ...                       ...          ...
# 30181           NaN            NaN                       NaN          NaN
# 30182           NaN            NaN                       NaN          NaN
# 30183           NaN            NaN                       NaN          NaN
# 30253           NaN            NaN                       NaN          NaN
# 30254           NaN            NaN                       NaN          NaN
#
#       hauteurarbre portarbre              structure  forme typenature  \
# 29735          NaN       NaN  Métropole de Grenoble    NaN        NaN
# 470            NaN       NaN  Métropole de Grenoble    NaN        NaN
# 466            NaN       NaN  Métropole de Grenoble    NaN        NaN
# 467            NaN       NaN  Métropole de Grenoble    NaN        NaN
# 468            NaN       NaN  Métropole de Grenoble    NaN        NaN
# ...            ...       ...                    ...    ...        ...
# 30181          NaN       NaN                    NaN    NaN        NaN
# 30182          NaN       NaN                    NaN    NaN        NaN
# 30183          NaN       NaN                    NaN    NaN        NaN
# 30253          NaN       NaN                    NaN    NaN        NaN
# 30254          NaN       NaN                    NaN    NaN        NaN
#
#                                 geo_point_2d
# 29735   45.201048144846105,5.706723350790874
# 470       45.16460473238141,5.73261246587306
# 466       45.1647781954654,5.732272344282779
# 467    45.164709478679775,5.7323456751313016
# 468      45.16468321095158,5.732404927856306
# ...                                      ...
# 30181    45.16303393970138,5.732067969329092
# 30182    45.16302875579452,5.731992034069511
# 30183    45.16218213317904,5.731317801401015
# 30253   45.16205678881154,5.7310363106312145
# 30254   45.162058811562765,5.731109431470176
#
# [31826 rows x 38 columns]

# %% [markdown]
# # Quelle est la proportion du genre botanique le plus représenté parmi tous les genres ?

# %% [markdown]
# # Quelle est la proportion de chacun des genres botaniques par rapport autotal ?

# %% [markdown]
# # Les objectifs de la Métro sont-ils respectés en termes de diversité ?

# %% [markdown]
# # Idem précédemment mais en comptant les espèces.

# %% [markdown]
# # (plus dur) Comment la pratique de plantation a-t-elle évolué au cours du temps ? Diversifie-t-on plus maintenant qu’avant ?
