# %%
import pandas as pd

# %%
data = pd.read_csv("trees.csv", sep = ';')
# Out:
# /tmp/ipykernel_29279/3019992069.py:1: DtypeWarning: Columns (22,23,26,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("trees.csv", sep = ';')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31826 entries, 0 to 31825
# Data columns (total 38 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   elem_point_id          31817 non-null  float64
#  1   code                   31826 non-null  object
#  2   nom                    31826 non-null  object
#  3   genre                  31826 non-null  object
#  4   genre_desc             31826 non-null  object
#  5   categorie              31817 non-null  object
#  6   categorie_desc         31817 non-null  object
#  7   sous_categorie         31817 non-null  object
#  8   sous_categorie_desc    31817 non-null  object
#  9   code_parent            31817 non-null  object
#  10  code_parent_desc       31817 non-null  object
#  11  adr_secteur            31808 non-null  float64
#  12  bien_reference         31808 non-null  object
#  13  genre_bota             31001 non-null  object
# ...

# %%
data.head(2)
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP991  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
#
#   diametrearbre  causeabattage       collectivite stationmetro  \
# 0           NaN            NaN  Ville de Grenoble          NaN
# 1           NaN            NaN  Ville de Grenoble          NaN
#
#      hauteurarbre portarbre          structure  forme typenature  \
# 0  de 10 m à 20 m     Libre  Ville de Grenoble   Tige      Libre
# 1    Plus de 20 m     Libre  Ville de Grenoble    NaN      Libre
#
#                           geo_point_2d
# 0  45.18599541005583,5.736390702744254
# 1  45.18535720117796,5.737112737684537
#
# [2 rows x 38 columns]

# %%
data.tail(50)
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 31776        23431.0  ESP28726  AR28726   VEG  VEGETATION     ESP01
# 31777        23432.0  ESP28727  AR28727   VEG  VEGETATION     ESP01
# 31778        20039.0  ESP28728  AR28728   VEG  VEGETATION     ESP01
# 31779        20043.0  ESP28729  AR28729   VEG  VEGETATION     ESP01
# 31780        20051.0  ESP28731  AR28731   VEG  VEGETATION     ESP01
# 31781        23811.0  ESP28734  AR28734   VEG  VEGETATION     ESP01
# 31782        23816.0  ESP28735  AR28735   VEG  VEGETATION     ESP01
# 31783        23820.0  ESP28736  AR28736   VEG  VEGETATION     ESP01
# 31784        23839.0  ESP28741  AR28741   VEG  VEGETATION     ESP01
# 31785        23844.0  ESP28742  AR28742   VEG  VEGETATION     ESP01
# 31786        23850.0  ESP28743  AR28743   VEG  VEGETATION     ESP01
# 31787        23862.0  ESP28746  AR28746   VEG  VEGETATION     ESP01
# 31788        23867.0  ESP28747  AR28747   VEG  VEGETATION     ESP01
# ...

# %% [markdown]
# # Extraire l’ensemble des lignes (rows) et stocker ces informations dans une variable de type List

# %%
all_rows_in_liste = []
for ligne in data :
    annee = data.loc[:,:]
    all_rows_in_liste.append(annee)
print(all_rows_in_liste )
# Out:
# [       elem_point_id      code      nom genre  genre_desc categorie  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION     ESP01
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION     ESP01
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION     ESP01
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION     ESP01
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %% [markdown]
# # Afficher les deux premières lignes de ce csv. Que représentent elles ?

# %%
deux_lignes = data.loc[0:1,]
deux_lignes
# Out:
#    elem_point_id      code      nom genre  genre_desc categorie  \
# 0        27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1        27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
#
#   categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# 0          Arbre         ESP174  Arbre d'espaces ouverts      ESP991  ...
# 1          Arbre         ESP174  Arbre d'espaces ouverts       ESP22  ...
#
#   diametrearbre  causeabattage       collectivite stationmetro  \
# 0           NaN            NaN  Ville de Grenoble          NaN
# 1           NaN            NaN  Ville de Grenoble          NaN
#
#      hauteurarbre portarbre          structure  forme typenature  \
# 0  de 10 m à 20 m     Libre  Ville de Grenoble   Tige      Libre
# 1    Plus de 20 m     Libre  Ville de Grenoble    NaN      Libre
#
#                           geo_point_2d
# 0  45.18599541005583,5.736390702744254
# 1  45.18535720117796,5.737112737684537
#
# [2 rows x 38 columns]

# %% [markdown]
# # Afficher la 2ème colonne de chacune de ces deux lignes.

# %%
deux_colonnes = data.iloc[:,0:1]
deux_colonnes
# Out:
#        elem_point_id
# 0            27452.0
# 1            27458.0
# 2            27461.0
# 3            27467.0
# 4            27470.0
# ...              ...
# 31821        27517.0
# 31822        27519.0
# 31823        27521.0
# 31824        27523.0
# 31825        27525.0
#
# [31826 rows x 1 columns]

# %% [markdown]
# # Extraire l’information concernant l’année de plantation pour l’ensemble des lignes (rows) et stocker ces informations dans une autre variable de type List

# %%
   
all_annee = data.anneedeplantation  
all_annee =all_annee.to_list()
type(all_annee)
# Out:
# list

# %% [markdown]
# # Afficher les 50 premières lignes et les 50 dernières lignes de cette liste.

# %%
ligne_50 = data.loc[0:50]
ligne_50
# Out:
#     elem_point_id      code      nom genre  genre_desc categorie  \
# 0         27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1         27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2         27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3         27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4         27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
# 5         27479.0  ESP29633  AR29633   VEG  VEGETATION     ESP01
# 6         27488.0  ESP29635  AR29635   VEG  VEGETATION     ESP01
# 7         27500.0  ESP29638  AR29638   VEG  VEGETATION     ESP01
# 8         27509.0  ESP29640  AR29640   VEG  VEGETATION     ESP01
# 9         27514.0  ESP29641  AR29641   VEG  VEGETATION     ESP01
# 10        27518.0  ESP29642  AR29642   VEG  VEGETATION     ESP01
# 11        14327.0  ESP29643  AR29643   VEG  VEGETATION     ESP01
# 12        14336.0  ESP29645  AR29645   VEG  VEGETATION     ESP01
# ...

# %%
dernieres_50 = data.iloc[:, -50:-1]
dernieres_50
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION     ESP01
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION     ESP01
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION     ESP01
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION     ESP01
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %% [markdown]
# # Combien d’arbres sont recensés dans ce jeu de données ?

# %%
data_lenght = len(data) 
data
# Out:
#        elem_point_id      code      nom genre  genre_desc categorie  \
# 0            27452.0  ESP29627  AR29627   VEG  VEGETATION     ESP01
# 1            27458.0  ESP29628  AR29628   VEG  VEGETATION     ESP01
# 2            27461.0  ESP29629  AR29629   VEG  VEGETATION     ESP01
# 3            27467.0  ESP29630  AR29630   VEG  VEGETATION     ESP01
# 4            27470.0  ESP29631  AR29631   VEG  VEGETATION     ESP01
# ...              ...       ...      ...   ...         ...       ...
# 31821        27517.0  ESP27738  AR27738   VEG  VEGETATION     ESP01
# 31822        27519.0  ESP27739  AR27739   VEG  VEGETATION     ESP01
# 31823        27521.0  ESP27740  AR27740   VEG  VEGETATION     ESP01
# 31824        27523.0  ESP27741  AR27741   VEG  VEGETATION     ESP01
# 31825        27525.0  ESP27742  AR27742   VEG  VEGETATION     ESP01
#
#       categorie_desc sous_categorie      sous_categorie_desc code_parent  ...  \
# ...

# %% [markdown]
# # Pour combien d’arbres manque-t-il l’information concernant la date de plantation ? (Vous pouvez essayer de le faire d’au moins deux manières différentes.)

# %%
arbres_manquantes = data.anneedeplantation.isna().sum()
arbres_manquantes
# meme chose que le code suivant
# Out:
# 1998

# %%
data_1 = len(data[data.anneedeplantation.isna()])
data_1
# Out:
# 1998

# %% [markdown]
# # Combien d’arbres ont été plantés l’année de votre naissance ?

# %%
nombre_arbre_annee_1983 = len(data[data.anneedeplantation == 1983])
nombre_arbre_annee_1983
# Out:
# 279

# %% [markdown]
# # Quelle est la plus ancienne année de plantation recensée dans ce dataset ?La plus récente ?

# %%
data_min = data['anneedeplantation'].min()
data_min
# Out:
# 1900.0

# %%
data_max = data['anneedeplantation'].max()
data_max
# Out:
# 2022.0

# %% [markdown]
# # Combien d’arbres ont été plantés année par année (ex : 1987 : 771, 1988 :266, etc...) ?

# %%
nombre_unique_arbre_annee = data["anneedeplantation"].value_counts()
nombre_unique_arbre_annee
# Out:
# anneedeplantation
# 1975.0    3452
# 2001.0    1449
# 1980.0    1359
# 1970.0    1293
# 2015.0    1004
#           ...
# 1900.0      25
# 1959.0      16
# 1924.0      11
# 1964.0       6
# 2021.0       5
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# # How do you use groupby in Python?pandas GroupBy: Your Guide to Grouping Data in Python – Real ...You call . groupby() and pass the name of the column that you want to group on, which is "state" . Then, you use ["last_name"] to specify the columns on which you want to perform the actual aggregation. You can pass a lot more than just a single column name to .

# %%
nombre_arbre_annee = data.groupby('anneedeplantation')["elem_point_id"].count()
nombre_arbre_annee
# Out:
# anneedeplantation
# 1900.0     25
# 1924.0     11
# 1944.0     26
# 1950.0    397
# 1955.0    113
#          ...
# 2018.0    871
# 2019.0    355
# 2020.0    172
# 2021.0      5
# 2022.0    215
# Name: elem_point_id, Length: 66, dtype: int64

# %% [markdown]
# # Combien d’arbres ont été plantés en moyenne chaque année ?

# %%
nombre_arbre_an = data.groupby('anneedeplantation')["elem_point_id"].count()
mean_arbre_an = nombre_arbre_an.mean()
mean_arbre_an
# Out:
# 451.93939393939394

# %% [markdown]
# # fonction .value_count()

# %%
unique_annee = data.anneedeplantation.value_counts()
unique_annee
# Out:
# anneedeplantation
# 1975.0    3452
# 2001.0    1449
# 1980.0    1359
# 1970.0    1293
# 2015.0    1004
#           ...
# 1900.0      25
# 1959.0      16
# 1924.0      11
# 1964.0       6
# 2021.0       5
# Name: count, Length: 66, dtype: int64

# %% [markdown]
# # Quel maire a planté le plus d’arbres à Grenoble ?

# %% [markdown]
# # Récupérez maintenant l’information concernant le genre botanique et la stocker conjointement avec l’année de plantation dans un tuple.
# # Les tuples seront stockés dans une liste (ex : [ (‘1987’, ‘Acer), (‘1988’, ‘Acerifolia), ..... ])

# %%
genre_botanique = data[['genre_bota', 'anneedeplantation']]
genre_botanique.head()
# Out:
#   genre_bota  anneedeplantation
# 0     Ginkgo             1965.0
# 1   Platanus             1965.0
# 2      Morus             1965.0
# 3      Taxus             1965.0
# 4       Acer             1965.0

# %%
type(genre_botanique)
# Out:
# pandas.core.frame.DataFrame

# %%
tuple_genre_botanique = tuple(genre_botanique )
tuple_genre_botanique
# Out:
# ('genre_bota', 'anneedeplantation')

# %%
type(tuple_genre_botanique)
# Out:
# tuple

# %% [markdown]
# # Pour combien d'arbres manque-t-il l’information concernant le genre botanique ?

# %%
genre_botanique_null = len(data[data['genre_bota'].isna()])
genre_botanique_null
# Out:
# 825

# %%
genre_botanique_null = data['genre_bota'].isna().sum()
genre_botanique_null
# Out:
# 825

# %%
data.isna().sum()
# Out:
# elem_point_id                9
# code                         0
# nom                          0
# genre                        0
# genre_desc                   0
# categorie                    9
# categorie_desc               9
# sous_categorie               9
# sous_categorie_desc          9
# code_parent                  9
# code_parent_desc             9
# adr_secteur                 18
# bien_reference              18
# genre_bota                 825
# espece                    2488
# variete                  27185
# stadededeveloppement      3873
# equipe                   31826
# remarques                26520
# anneedeplantation         1998
# raisondeplantation       28516
# traitementchenilles      29730
# courrier                 31817
# identifiantplu           31223
# typeimplantationplu      26788
# intituleprotectionplu    31232
# anneeabattage            31817
# essouchement             31817
# diametrearbre            31817
# causeabattage            31826
# ...

# %% [markdown]
# # Utilisez Matplotlib pour tracer l’histogramme représentant le nombre d’arbres plantés par année.

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(data.anneedeplantation, bins = 20)
# Out:
# (array([  25.,    0.,    0.,   11.,    0.,    0.,    0.,   26.,  397.,
#          825.,  860., 2091., 6325., 4027., 1768., 1846., 3251., 2247.,
#         3372., 2757.]),
#  array([1900. , 1906.1, 1912.2, 1918.3, 1924.4, 1930.5, 1936.6, 1942.7,
#         1948.8, 1954.9, 1961. , 1967.1, 1973.2, 1979.3, 1985.4, 1991.5,
#         1997.6, 2003.7, 2009.8, 2015.9, 2022. ]),
#  <BarContainer object of 20 artists>)
